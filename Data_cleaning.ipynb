# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/tosa/Desktop/Analytics/Obce.xlsx")
df
# Out:
#                             Nazev    PSC  Obyvatel             Kraj  \
# 0     Magistrát hlav. města Praha  11000   1161938      Hl.m. Praha
# 1            Magistrát města Brno  60167    370505     Jihomoravský
# 2         Magistrát města Ostrava  72930    314102  Moravskoslezský
# 3           Magistrát města Plzeň  30632    164703         Plzeňský
# 4         Magistrát města Olomouc  77127    101624        Olomoucký
# ...                           ...    ...       ...              ...
# 6241                 Vysoká Lhota  39501        26         Vysočina
# 6242                       Bludov  28542        25      Středočeský
# 6243                         Čilá  33808        25         Plzeňský
# 6244                     Hraditě  33810        24         Plzeňský
# 6245                        Vlkov  37363        20        Jihočeský
#
#                    Okres Posta  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0     Hlavní město Praha   ANO         NaN         NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['Nazev', 'PSC', 'Obyvatel', 'Kraj', 'Okres', 'Posta', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
df = df[['Nazev', 'PSC', 'Obyvatel', 'Kraj', 'Okres', 'Posta']]
df
# Out:
#                             Nazev    PSC  Obyvatel             Kraj  \
# 0     Magistrát hlav. města Praha  11000   1161938      Hl.m. Praha
# 1            Magistrát města Brno  60167    370505     Jihomoravský
# 2         Magistrát města Ostrava  72930    314102  Moravskoslezský
# 3           Magistrát města Plzeň  30632    164703         Plzeňský
# 4         Magistrát města Olomouc  77127    101624        Olomoucký
# ...                           ...    ...       ...              ...
# 6241                 Vysoká Lhota  39501        26         Vysočina
# 6242                       Bludov  28542        25      Středočeský
# 6243                         Čilá  33808        25         Plzeňský
# 6244                     Hraditě  33810        24         Plzeňský
# 6245                        Vlkov  37363        20        Jihočeský
#
#                    Okres Posta
# 0     Hlavní město Praha   ANO
# 1             Brno-město   ANO
# 2          Ostrava-město   ANO
# ...
